# %% [markdown]
# ### 오승혁님 과제
#
# #### 체크사항
#
# - condition one-liner

# %%
from IPython.core.prefilter import PythonOpsChecker
"영화의 장르를 선택해 주세요"
genre_list=['romance','comedy','Action']
if genre_list[0]: print("영화의 장르는",genre_list[0],"입니다.")
if genre_list[1]: print("영화의 장르는",genre_list[1],"입니다.")
if genre_list[2]: print("영화의 장르는",genre_list[2],"입니다.")
'영화의 제목을 입력하세요'
title_dict={"romance":'movie1',"comedy":'movie2',"Action":'movie3'}
if "romance": print("영화의 제목:",title_dict["romance"])
if "comedy": print ("영화의 제목:",title_dict["comedy"])
if "Action": print ("영화의 제목:",title_dict["Action"])
starting_time_dict={"romance":'오후1시20분',"comedy":'오후3시',"Action":'오후2시30분'}
if "romance": print(starting_time_dict["romance"])
if "comedy": print(starting_time_dict["comedy"])
if "Action": print(starting_time_dict["Action"])
'모든 관람자의 나이를 입력하여 주시기 바랍니다.'
for age in range(50):
    if age>19: print(age,"세는 관람 가능합니다")
    else:
        print(age,"세는 관람 불가능합니다")
price_dict={"성인":10000,"미성년자":5000}
if "성인":print(price_dict["성인"],"원 입니다")
elif "미성년자":print(price_dict["미성년자"],"원 입니다")
# Out:
# 영화의 장르는 romance 입니다.
# 영화의 장르는 comedy 입니다.
# 영화의 장르는 Action 입니다.
# 영화의 제목: movie1
# 영화의 제목: movie2
# 영화의 제목: movie3
# 오후1시20분
# 오후3시
# 오후2시30분
# 0 세는 관람 불가능합니다
# 1 세는 관람 불가능합니다
# 2 세는 관람 불가능합니다
# 3 세는 관람 불가능합니다
# 4 세는 관람 불가능합니다
# 5 세는 관람 불가능합니다
# 6 세는 관람 불가능합니다
# 7 세는 관람 불가능합니다
# 8 세는 관람 불가능합니다
# 9 세는 관람 불가능합니다
# 10 세는 관람 불가능합니다
# 11 세는 관람 불가능합니다
# 12 세는 관람 불가능합니다
# 13 세는 관람 불가능합니다
# 14 세는 관람 불가능합니다
# 15 세는 관람 불가능합니다
# 16 세는 관람 불가능합니다
# 17 세는 관람 불가능합니다
# 18 세는 관람 불가능합니다
# 19 세는 관람 불가능합니다
# 20 세는 관람 가능합니다
# 21 세는 관람 가능합니다
# 22 세는 관람 가능합니다
# 23 세는 관람 가능합니다
# 24 세는 관람 가능합니다
# 25 세는 관람 가능합니다
# 26 세는 관람 가능합니다
# 27 세는 관람 가능합니다
# 28 세는 관람 가능합니다
# 29 세는 관람 가능합니다
# 30 세는 관람 가능합니다
# 31 세는 관람 가능합니다
# 32 세는 관람 가능합니다
# 33 세는 관람 가능합니다
# 34 세는 관람 가능합니다
# 35 세는 관람 가능합니다
# 36 세는 관람 가능합니다
# 37 세는 관람 가능합니다
# 38 세는 관람 가능합니다
# 39 세는 관람 가능합니다
# 40 세는 관람 가능합니다
# 41 세는 관람 가능합니다
# 42 세는 관람 가능합니다
# 43 세는 관람 가능합니다
# 44 세는 관람 가능합니다
# 45 세는 관람 가능합니다
# 46 세는 관람 가능합니다
# 47 세는 관람 가능합니다
# 48 세는 관람 가능합니다
# ...

# %% [markdown]
# ### 조하영님 과제
#
# #### 체크사항
#
# - perfect
# - about sys.argv
# - 함수를 배우지 않았다고 가정했을 때의 최상의 답안
# - line 33에서의 range-i 구문 Not pythonic, enumerate() 사용법 확인

# %%
#상영중인 영화 정보를 전역 변수로 설정
movie1 = {"title":"정직한 후보2","running_time":"107","start_time":"오후 1시 45분","limited_age":"12","genre":"comedy"}
movie2 = {"title":"인생은 아름다워","running_time":"122","start_time":"오후 1시 55분","limited_age":"12","genre":"musical"}
movie3 = {"title":"공조2: 인터내셔날","running_time":"129","start_time":"오후 2시 10분","limited_age":"15","genre":"action"}
movie_list = [movie1, movie2, movie3]

import sys
argument = sys.argv

if len(argument) > 2 :
    print('Error')
    exit()
elif len(argument) == 1 : #사용자 모드 python main.py
    while(1):
        print("=========================================")
        print("상영중인 영화 정보".center(28))
        print("=========================================")
        print(movie_list)

        #성인, 경로, 아동 관련 정보영
        adult_count = 0
        child_count = 0
        senior_count = 0
        adult_price = 10000
        child_price = 6000 #19세 이하
        senior_price = 8000 #65세 이상

        #영화 이름
        print("=========================================")
        movie_title = input(">>> 예매하실 영화의 이름을 입력하세요. ")
        if movie_title == 'exit': exit()
        name_mismatch=0 #영화 이름이 잘못 입력되었음을 확인하기 위한 변수
        for i in range(len(movie_list)):
            if movie_title == movie_list[i]["title"]:
                temp = movie_list[i]
            else:
                name_mismatch += 1

        if name_mismatch == len(movie_list):
            print("=========================================")
            print("안내".center(28))
            print("=========================================")
            print("잘못된 영화 이름입니다. 다시 확인하여 주세요.")
            print("=========================================")
            continue

        #나이 확인
        age_list = input(">>> 모든 관람자의 나이를 입력하여 주시기 바랍니다. 띄어쓰기로 구분하십시오. ").split(" ")
        if age_list[0] == 'exit': exit()
        i_index = 0
        for i in range(len(age_list)):
            if age_list[i_index] < temp["limited_age"]:
                print("=========================================")
                print("안내".center(28))
                print("=========================================")
                print("본 영화는", temp["limited_age"], "세 이상이 관람할 수 있습니다.", age_list[i_index],"세인 해당 인원을 제외합니다.")
                print("=========================================")
                del age_list[i_index]
                if i_index != 0 : i_index -= 1
            else: i_index += 1

        if len(age_list) == 0 : #모두 관람 불가능한 연령일 때
            print("취소되었습니다. 처음부터 다시 시도하여 주세요.")
            continue

        #영화 가격
        total_price = 0
        for i in age_list:
            if int(i) <= 19 :
                total_price += child_price
                child_count += 1
            elif 19 < int(i) < 65 :
                total_price += adult_price
                adult_count += 1
            elif int(i) >= 65 :
                total_price += senior_price
                senior_count += 1

        print("=========================================")
        print("예매 안내".center(28))
        print("=========================================")
        print("총", len(age_list),"명이며, 결제 금액은",total_price,"원 입니다")
        print("=========================================")
        receipt = {"금액" : total_price, "경로" : senior_count, "어른" : adult_count, "아동":child_count, "영화명" : temp["title"], "총원" : len(age_list)}

        y_n = input(">>> 예매하시겠습니까? 예매를 하시려면 'Y' 또는 'N'를 입력하십시오. ")
        if y_n == 'exit': exit()
        print("=========================================")
        if(y_n == 'Y'):
            print("예매 영수증".center(28))
            print("=========================================")
            print(receipt)
            print("=========================================")
        else:
            print("안내".center(28))
            print("=========================================")
            print("취소되었습니다. 처음부터 다시 시도하여 주세요.")
            print("=========================================")
            continue

else: #관리자 모드 python main.py admin
    if (argument[1] == "admin"):
        while(1):
            print("=========================================")
            print("저장된 영화 정보".center(28))
            print("=========================================")
            print(movie_list)
            print("=========================================")

            text = input(">>> 입력을 원하시면 '입력'을 입력하십시오. ")
            if text == 'exit':
                print("프로그램이 종료되었습니다.")
                exit()
            elif text == "입력" :
                new_movie = {"title":"","running_time":"","start_time":"","limited_age":"","genre":""}
                new_movie_info = input(">>> 영화명, 상영시간, 시작시간, 관람제한연령, 영화장르 순으로 띄어쓰기로 구분하여 데이터를 입력하십시오. ").split(" ")
                if new_movie_info == 'exit':
                    print("프로그램이 종료되었습니다.")
                    exit()
                new_movie['title'] = new_movie_info[0]
                new_movie['running_time'] = new_movie_info[1]
                new_movie['start_time'] = new_movie_info[2]
                new_movie['limited_age'] = new_movie_info[3]
                new_movie['genre'] = new_movie_info[4]
                movie_list.append(new_movie)
                print("=========================================")
                print("안내".center(28))
                print("=========================================")
                print("영화", new_movie['title'], "이(가) 등록되었습니다.")
                print("=========================================")
            else:
                print("취소되었습니다. 처음부터 다시 시도하여 주세요.")
                continue

# %% [markdown]
# ### 김형중, 한수연님 과제
#
# #### 체크사항
#
# - meaningless variable naming with camel-case
# - whitespace in Expression and statements (Always surround these binary operators with a single space on either side: assignment (=), augmented assignment (+=, -= etc.), comparisons (==, <, >, !=, <>, <=, >=, in, not in, is, is not), Booleans (and, or, not)., PEP8)

# %%
print('=' * 40)
print('           상영 중인 영화 정보            ')
a= {'genre': 'Comedy',
  'limited_age': 12,
  'running_time': 120,
  'start_time': '오후 1시 15분',
  'title': '정직한 후보들'}
b= {'genre': 'Action',
  'limited_age': 19,
  'running_time': 70,
  'start_time': '오후 1시 35분',
  'title': '아저씨'}
c = {'genre': 'Comedy',
  'limited_age': 0,
  'running_time': 80,
  'start_time': '오후 2시 00분',
  'title': '덤앤더머'}
choice0 = input("예매하실 영화의 이름을 입력하세요:")
choice1 = input("모든 관람자의 나이를 입력해주시기 바랍니다. 띄어쓰기로 구분하십시오.:")
print("영화는 19세이상이 관람할 수 있습니다. 10세인 해당 인원을 제외합니다.")
print('=' * 40)
print(b['title'])
ages = [10, 20, 30]
for age in ages:
    if age < 19:
        cost = 8000
    else:
        cost = 10000
print('=' * 40)
print("               안내             ")
new_ages = [age for age in ages if age > 19]
print('=' * 40)
print('=' * 40)
print("               예매 안내               ")
print('=' * 40)
n = len(new_ages)
m = (cost * 2)
print("총 %d명, %d원" %(n,m))
print('=' * 40)
choice = input(">>> 예매하시겠습니까? 예매를 하시려면 'Y'또는 'y'를 입력하십시오.")
if choice =='Y':
    print('=' * 40)
print("            예매 영수증               ")
print('=' * 40)
print('=' * 40)
print("              상영중인 영화 정보             ")
print('=' * 40)
movie_a = {'genre': 'Comedy',
  'limited_age': 12,
  'running_time': 120,
  'start_time': '오후 1시 15분',
  'title': '정직한 후보들'}
movie_b = {'genre': 'Action',
  'limited_age': 19,
  'running_time': 70,
  'start_time': '오후 1시 35분',
  'title': '아저씨'}
movie_c = {'genre': 'Comedy',
  'limited_age': 0,
  'running_time': 80,
  'start_time': '오후 2시 00분',
  'title': '덤앤더머'}
for key, value in movie_a.items():
    print(key, ":", value)
print('-' * 40)
for key, value in movie_b.items():
    print(key,":", value)
print('-' * 40)
for key, value in movie_c.items():
    print(key,":", value)
print('=' * 40)

# %%
import sys

# 영화 정보를 저장할 리스트
movies = [{'genre': 'Comedy',
  'limited_age': 12,
  'running_time': 120,
  'start_time': '오후 1시 15분',
  'title': '영화1'},
 {'genre': 'Action',
  'limited_age': 19,
  'running_time': 70,
  'start_time': '오후 1시 35분',
  'title': '영화2'},
 {'genre': 'Comedy',
  'limited_age': 0,
  'running_time': 80,
  'start_time': '오후 2시 00분',
  'title': '영화3'}]

# 관리자모드
if len(sys.argv) == 2 and sys.argv[1] == 'admin':
    while True:
        print('===========================================')
        print('저장된 영화 정보')
        print('===========================================')
        for movie in movies:
            print(movie)
        print('===========================================')
        a=input('입력을 원하시면 "입력"을 입력하십시오')
        if a=='입력':
            b=input('영화명, 상영시간, 시작시간, 관람제한연령, 영화장르 순으로 띄어쓰기로 구분하여 데이터를 입력하십시오.')
            b=b.split()
            movies.append({'title':b[0],'running_time':int(b[1]),'start_time':b[2],'limited_age':int(b[3]),'genre':b[4]})
        elif a=='exit':
            break
        else:
            print('잘못된 입력입니다.')
# 사용자모드
else:
    while True:
        print('===========================================')
        print('상영중인 영화 정보')
        print('===========================================')
        print(movies)
        print('===========================================')
        b=[]
        while True:
            a=input('예매하실 영화의 이름을 입력하세요.')
            if a=='exit':
                print('프로그램이 종료되었습니다.')
                sys.exit()
            for i in movies:
                if i['title']==a:
                    b.append(i)
                    break
                else:
                    continue
            print('===========================================')
            print('안내')
            print('===========================================')
            if b==[] or b==None and a!='exit':
                print('잘못된 영화 이름입니다. 다시 확인하여 주세요.')
                continue
            else:
                c=input('모든 관람자의 나이를 입력하여 주시기 바랍니다. 띄어쓰기로 구분하십시오.')
                if c=='exit':
                    print('프로그램이 종료되었습니다.')
                    sys.exit()
                c=c.split()
                d=[]
                for i in c:
                    if int(i)<int(b[0]['limited_age']):
                        d.append(i)
                        c.remove(i)
                    else:
                        continue
                print('===========================================')
                print('안내')
                print('===========================================')
                if d==[]:
                    print('모든 관람자의 나이가 관람제한 연령 이상입니다.')
                    break
                else:
                    print('본 영화는',b[0]['limited_age'],'세 이상이 관람할 수 있습니다.',d,'세인 해당 인원을 제외합니다.')
                    break
        e=0
        g=0
        h=0
        j=0
        for i in c:
            if int(i)>=60:
                e=e+5000
                g=g+1
            elif int(i)<60 and int(i)>=20:
                e=e+10000
                h=h+1
            else:
                e=e+7000
                j=j+1
        print('===========================================')
        print('예매 안내')
        print('===========================================')
        print('총',len(c),'명이며','결제금액은', e,'원 입니다.')
        print('===========================================')
        f=input('예매하시겠습니까? 예매를 하시려면 "Y"또는 "y"를 입력하십시오.')
        if f=='Y' or f=='y':
            print('===========================================')
            print('예매 영수증')
            print('===========================================')
            print('경로:',g ,'명, 성인:',h,'명, 아동:',j,'명, 금액:',e,'원, 영화명:',b[0]['title'],'총원:',len(c))
            print('===========================================')
            break
        else:
            print('===========================================')
            print('안내')
            print('===========================================')
            print('취소되었습니다. 처음부터 다시 시도하여 주세요.')
            continue
# Out:
# ...
# 상영중인 영화 정보
# ...
# [{'genre': 'Comedy', 'limited_age': 12, 'running_time': 120, 'start_time': '오후 1시 15분', 'title': '영화1'}, {'genre': 'Action', 'limited_age': 19, 'running_time': 70, 'start_time': '오후 1시 35분', 'title': '영화2'}, {'genre': 'Comedy', 'limited_age': 0, 'running_time': 80, 'start_time': '오후 2시 00분', 'title': '영화3'}]
# ...
# 안내
# ...
# 안내
# ...
# 본 영화는 12 세 이상이 관람할 수 있습니다. ['10'] 세인 해당 인원을 제외합니다.
# ...
# 예매 안내
# ...
# 총 2 명이며 결제금액은 20000 원 입니다.
# ...
# 예매 영수증
# ...
# 경로: 0 명, 성인: 2 명, 아동: 0 명, 금액: 20000 원, 영화명: 영화1 총원: 2
# ...

# %% [markdown]
# ### 제다현님 과제
#
# #### 체크사항
#
# - indent Error (Indentation, Use 4 spaces per indentation level. Spaces are the preferred indentation method.)

# %%
# -*- coding: utf-8 -*-
"""ibas_1

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1a3svDzARRvpLz6POOZQ-gzWqtZ1NxfZf
"""

# Commented out IPython magic to ensure Python compatibility.
while True:
  print('='*30)
  print('상영중인 영화 정보')
  print('='*30)

  m1=dict()
  m1={}
  m1={'genre': 'Comedy','limited_age': 12,'running_time': 120,'start_time': '오후 1시 15분','title': '영화1'}

  m2=dict()
  m2={}
  m2={'genre': 'Action','limited_age': 19,'running_time': 70,'start_time': '오후 1시 35분','title': '영화2'}

  m3=dict()
  m3={}
  m3={'genre': 'Comedy','limited_age': 0, 'running_time': 80,'start_time': '오후 2시 00분','title': '영화3'}

  print(m1, m2, m3)
  print('='*30)

  name=input('>>> 예매하실 영화의 이름을 입력하세요')
  if name=='exit':
    print('프로그램이 종료되었습니다.')
    break

  pick=[]
  if name in m1['title']:
    pick=m1
  elif name in m2['title']:
    pick=m2
  elif name in m3['title']:
    pick=m3
  else:
    print('잘못된 영화 이름입니다. 다시 확인하여 주세요.')
    continue

  age=list(map(int, input('>>> 모든 관람자의 나이를 입력하여 주시기 바랍니다. 띄어쓰기로 구분하십시오.').split()))
  print('='*30)
  count=len(age)
  old=[]
  adult=[]
  child=[]
  for i in range(0,count,1):
    if age[i]>=70:
      old.append(age[i])
    elif 70>age[i]>=8:
      adult.append(age[i])
    elif age[i]<8:
      child.append(age[i])

  print('='*30)
  print('안내')
  print('='*30)
  nchild=[]
  nadult=[]
  for i in range(0,len(child)-1,1):
    if child[i] < pick['limited_age']:
      nchild.append(child[i])
      child.remove(child[i])
  for i in range(0,len(adult)-1,1):
    if adult[i] < pick['limited_age']:
      nadult.append(adult[i])
      adult.remove(adult[i])
  print('본 영화는', pick['limited_age'], '세 이상이 관람할 수 있습니다.')
  if len(nchild)>0:
    print(nchild, '세인 해당 인원을 제외합니다.')
  if len(nadult)>0:
    print(nadult, '세인 해당 인원을 제외합니다.')

  print('='*30)
  print('예매 안내')
  print('='*30)
  price=5000*len(child) + len(adult)*10000 + len(old)*5000
  n=len(child)+len(adult)+len(old)
  print("총",n,"명이며,","결제금액은", price,"원입니다.")

  print('='*30)
  ans=input(">>> 예매하시겠습니까? 예매를 하시려면 'Y'또는 'y'를 입력하십시오")
  print('='*30)
  if ans=='Y' or ans=='y':
    print('='*30)
    print('예매 영수증')
    print('='*30)
    print("{'경로': '%d명', '금액': '%d원', '성인': '%d명', '아동': '%d명', '영화명': '%s', '총원': '%d명'}" %(len(old), price, len(adult), len(child), name, n))
    print('='*30)

  else:
    print('='*30)
    print('안내')
    print('='*30)
    print('취소되었습니다. 처음부터 다시 시도하여 주세요.')
    print('='*30)
    continue

admin=input()
  if admin=='python main.py admin':
    print('='*30)
    print('저장된 영화 정보')
    print('='*30)
    print(m1,m2,m3)
    print('='*30)

    con=input(">>> 입력을 원하시면 '입력'을 입력하십시오.")
    if con=='입력':
      new=list(input('영화명, 상영시간, 시작시간, 관람제한연령, 영화장르 순으로 띄어쓰기로 구분하여 데이터를 입력하십시오.').split())
      print(new)
      nmov=dict()
      nmov={}
      nmov={'genre': new[4],'limited_age': new[3],'running_time': new[2],'start_time': new[1],'title': new[0]}

      print('='*30)
      print('안내')
      print('='*30)
      print('영화', new[0], '이(가) 등록되었습니다.')
      print('='*30)

      print('='*30)
      print('저장된 영화 정보')
      print('='*30)
      print(m1,m2,m3,nmov)

    else con=='exit':
      print('프로그램이 종료되었습니다')
      break
# Out:
#   Cell In [6], line 106
#     if admin=='python main.py admin':
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### 채한준님 과제
#
# #### 체크사항
#
# - PEP 8: E251 unexpected spaces around keyword / parameter equals

# %%
# -*- coding: utf-8 -*-
"""1주차 과제 .ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1YcLHKNxdZIFV8bSRnznN1EIib3oQ_K1F
"""

#영화관 키오스크 프로그램은 다음의 조건을 만족하여야 합니다.

# 1. 키오스크 프로그램은 관리자 모드와 사용자 모드로 구분되어야 합니다. 각 모드의 기능은 각 모드에서만 작동하여야 합니다. 즉, 다른 모드에서 사용할 수 없습니다.
# 2. 모든 입력에 대하여 사용자가 `exit`를 입력하면 프로그램은 그 즉시 종료됩니다.
# 3. 사용자 모드에서는 아래의 기능을 추가하여야 합니다.
#     1. 기본적으로 프로그램을 실행하면 사용자 모드로 진입합니다.
#     2. 상영중인 영화의 정보를 제공하여야 합니다.
#         1. 관리자 모드로 진입하지 않아도 고정적으로 제공하는 영화 3가지를 지정하십시오.
#         2. `영화명, 상영시간, 시작시간, 관람제한연령, 영화장르 등`의 정보를 제공하여야하며, 영화 정보는 현실의 영화를 따르지 아니하여도 됩니다.
#         3. 상영중인 영화를 예매할 수 있어야합니다. 예매의 경우 반드시 `관람 연령을 확인하여야 합니다.`
#         4. 좌석은 선택하거나 선택하지 아니하여도 됩니다.
#         5. `성인/어린이/경로` 3가지의 요금을 다르게 하여, 여러 명의 요금을 합산하여 총 금액을 제시합니다.
#     3. 영화 선택 및 예매가 완료되면 영수증을 출력하여 해당 예매사항을 다시 확인할 수 있어야 합니다.
#     4. 프로그램 종료 명령이 있을 때까지 프로그램은 중단되지 아니하고 사용자 모드로 진행되어야 합니다.
# 4. 관리자 모드에서는 아래의 기능을 추가하여야 합니다.
#     1. 관리자 모드는 아래의 명령으로 실행할 수 있어야 합니다.
#         ⌨️ $ python [main.py](http://main.py) admin
#     2. 현재 상영 중인 영화를 추가할 수 있어야 합니다. 입력하여야하는 정보는 위 3.b.ii를 참조하십시오. 입력 후 모든 영화의 정보를 출력하여야 합니다.
#     3. 관리자모드 종료는 `exit`명령으로 종료할 수 있습니다.
#     <aside>
#     </aside>



moviename = "▒상영중인 영화 정보▒\n1.미니언즈(70분): 장르 -> 코미디(전체이용가)-> 시작시간: 17:50 가격 30000원(성인) \n2. 범죄도시(90분): 장르 -> 액션(청소년관람불가)-> 시작시간: 14:20 가격 30000원(성인)\n3. 토르 러브 앤 썬더(80분): 장르 -> 코미디(15세이용가) -> 시작시간: 19:15 가격 30000원(성인)"
what = '무엇을 얘매하시겠습니까? 숫자로 입력해주세요 : '
more = '주문을 더 하신다면 1번\n결제하시려면 2번을 눌러주세요 : '
totalMsg = '총 계산금액은 '
name = ["미니언즈", "범죄도시", "토르 러브 앤 썬더"]
price = [10000, 10000, 10000]
age = ["성인"," 청소년", "경로"]
order = []
ageprice = [0,3000,4000]
total = 0
change = 0
import sys
while True:
    print(moviename)
    choice = int(input(what))
    if choice == 1:
        order.append('미니언즈')
        total += price[0]
        while True:
            choice = int(input(more))
            if choice == 1:
                choice = int(input(what))
                if choice == 1:
                    order.append("미니언즈")
                    total += price[0]
                    continue
                elif choice == 2:
                    order.append("범죄도시")
                    total += price[1]
                    continue
                elif choice == 3:
                    order.append('토르 러브 앤 썬더')
                    total += price[2]
            else:
                break
            sys.exit(0)
    elif choice == 2:
        order.append("범죄도시")
        total += price[1]
        while True:
            choice = int(input(more))
            if choice == 1:
                choice = int(input(what))
                if choice == 1:
                    order.append("미니언즈")
                    total += price[0]
                    continue
                elif choice == 2:
                    order.append("범죄도시")
                    total += price[1]
                    continue
                elif choice == 3:
                    order.append("토르 러브 앤 썬더")
                    total += price[2]
            else:
                break
            sys.exit(0)
    elif choice == 3:
        order.append("토르 러브 앤 썬더")
        total += price[1]
        while True:
            choice = int(input(more))
            if choice == 1:
                choice = int(input(what))
                if choice == 1:
                    order.append("미니언즈")
                    total += price[0]
                    continue
                elif choice == 2:
                    order.append("범죄도시")
                    total += price[1]
                    continue
                elif choice == 3:
                    order.append("토르 러브 앤 썬더")
                    total += price[2]
            else:
                break
            sys.exit(0)
    print("나이를 성인, 청소년, 경로 중 하나를 택해주세요:")
    age = input()
    if age == "성인":
      change = total - ageprice[0]
      print("주문 내역은", end = " ")
      print(order)
      print('\n' + totalMsg + str(change) + '원 입니다.')
      break
      sys.exit(0)
    elif age == "청소년":
      change = total - ageprice[1]
      print("주문 내역은", end = " ")
      print(order)
      print('\n' + totalMsg + str(change) + '원 입니다.')
      break
      sys.exit(0)
    elif age == "경로":
      change = total - ageprice[2]
      print("주문 내역은", end = " ")
      print(order)
      print('\n' + totalMsg + str(change) + '원 입니다.')
      break
      sys.exit(0)

# %% [markdown]
# ### 조윤수님 과제
#
# #### 체크사항
#
# - PEP 8: E231 missing whitespace after ','

# %%
# -*- coding: utf-8 -*-
"""1주차 과제.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1Q61iNUMJn-FufXcxg1hS1d6XPyZQgiH9
"""

import pprint
import sys

mov1 = {'genre': 'Comedy',
  'limited_age': 12,
  'running_time': 120,
  'start_time': '오후 1시 15분',
  'title': '영화1'}

mov2 = {'genre': 'Action',
  'limited_age': 19,
  'running_time': 70,
  'start_time': '오후 1시 35분',
  'title': '영화2'}

mov3 = {'genre': 'Comedy',
  'limited_age': 0,
  'running_time': 80,
  'start_time': '오후 2시 00분',
  'title': '영화3'}

movlist = [mov1, mov2, mov3]

if len(sys.argv) == 2:
  if sys.argv[1] == "admin":
    while True:
      print("==================================================")
      print("                저정된 영화 정보                ")
      print("==================================================")
      print('-'*50)
      pprint.pprint(movlist)
      print("==================================================")
      aq1 = input(">>> 입력을 원하시면 '입력'을 입력하십시오.")
      if aq1 == "exit":
        print("프로그램이 종료되었습니다.")
        break;
      elif aq1 == "입력":
        aq2 = input(">>> 영화명, 상영시간, 시작시간, 관람제한연령, 영화장르 순으로 띄어쓰기로 구분하여 데이터를 입력하십시오.").split()
        if aq2 == "exit":
          print("프로그램이 종료되었습니다.")
          break;
        else:
          mov4 = {}
          mov4['genre'] = aq2[4]
          mov4['limited_age'] = int(aq2[3])
          mov4['running_time'] = int(aq2[1])
          mov4['start_time'] = aq2[2]
          mov4['title'] = aq2[0]
          movlist.append(mov4)
          print("==================================================")
          print("                       안내                       ")
          print("==================================================")
          print("영화",aq2[0],"이(가) 등록되었습니다.")
          print("==================================================")

elif len(sys.argv) > 2:
  print("Error")

else:
  while True:
    print("==================================================")
    print("               상영중인 영화 정보               ")
    print("==================================================")
    print('-'*50)
    pprint.pprint(movlist)
    print("==================================================")

    titlist = []
    for i in range(len(movlist)):
      titlist.append(movlist[i].get('title'))

    q1 = input(">>> 예매하실 영화의 이름을 입력하세요.")
    if q1 == "exit":
      print("프로그램이 종료되었습니다.")
      break;
    for i in range(len(movlist)):
      if movlist[i].get('title') == q1:
        k = movlist[i].get('limited_age')

    if q1 in titlist:
      q2f = input(">>> 모든 관람자의 나이를 입력하여 주시기 바랍니다. 띄어쓰기로 구분하십시오.")
      if q2f == "exit":
        print("프로그램이 종료되었습니다.")
        break;
      q2 = list(map(int,q2f.split()))
      q2.sort()
      print("==================================================")
      print("                       안내                       ")
      print("==================================================")
      for j in range(len(q2)):
        if q2[j] < k:
          print("본 영화는",k,"세 이상이 관람할 수 있습니다.",q2[j],"세인 해당 인원을 제외합니다.")
      b = 0
      for e in range(len(q2)):
        if q2[b] < k:
          del q2[b]
        elif q2[b] >= k:
          b = b + 1
      price = 0
      old = 0
      adult = 0
      young = 0
      for f in range(len(q2)):
        if q2[f] < 20:
          price = price + 5000
          young = young + 1
        elif q2[f] >= 20 and q2[f] < 65:
          price = price + 10000
          adult = adult + 1
        elif q2[f] >= 65:
          price = price + 7000
          old = old + 1
      rec = {}
      rec['영화명'] = q1
      rec['금액'] = str(price) + '원'
      rec['총원'] = str(len(q2)) + '명'
      rec['경로'] = str(old) + '명'
      rec['성인'] = str(adult) + '명'
      rec['아동'] = str(young) + '명'
      print("==================================================")
      print("==================================================")
      print("                    예매 안내                    ")
      print("==================================================")
      print("총",len(q2),"명이며, 결제금액은",price,"원입니다.")
      print("==================================================")
      q3 = input(">>> 예매하시겠습니까? 예매를 하시려면 'Y'또는 'y'를 입력하십시오.")
      if q3 == "exit":
        print("프로그램이 종료되었습니다.")
        break;
      elif q3 == "Y" or q3 == "y":
        print("==================================================")
        print("                   예매 영수증                   ")
        print("==================================================")
        print(rec)
        print("==================================================")
      else:
        print("==================================================")
        print("                       안내                       ")
        print("==================================================")
        print("취소되었습니다. 처음부터 다시 시도하여 주세요.")
        print("==================================================")

    else:
      print("==================================================")
      print("                       안내                       ")
      print("==================================================")
      print("잘못된 영화 이름입니다. 다시 확인하여 주세요.")
      print("==================================================")
